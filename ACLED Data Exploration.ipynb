# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/davidhmphm/Georgetown_ACLED/main/2018-05-07-2021-05-15-Brazil.csv')

# %%
'head(x) shows the top x results of the dataframe'
df.head(10)
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty   event_date  year  \
# 0  7938816   76      BRA41159             41159  07 May 2021  2021
# 1  7938817   76      BRA41202             41202  07 May 2021  2021
# 2  7938684   76      BRA41074             41074  07 May 2021  2021
# 3  7938687   76      BRA41205             41205  07 May 2021  2021
# 4  7938180   76      BRA41050             41050  07 May 2021  2021
# 5  7938181   76      BRA41190             41190  07 May 2021  2021
# 6  7938695   76      BRA41142             41142  07 May 2021  2021
# 7  7938702   76      BRA41212             41212  07 May 2021  2021
# 8  7938958   76      BRA41229             41229  07 May 2021  2021
# 9  7938703   76      BRA41211             41211  07 May 2021  2021
#
#    time_precision event_type         sub_event_type  \
# 0               1   Protests       Peaceful protest
# 1               1   Protests       Peaceful protest
# 2               1   Protests       Peaceful protest
# ...

# %%
'what columns can we select?'
list(df.columns)
# Out:
# ['data_id',
#  'iso',
#  'event_id_cnty',
#  'event_id_no_cnty',
#  'event_date',
#  'year',
#  'time_precision',
#  'event_type',
#  'sub_event_type',
#  'actor1',
#  'assoc_actor_1',
#  'inter1',
#  'actor2',
#  'assoc_actor_2',
#  'inter2',
#  'interaction',
#  'region',
#  'country',
#  'admin1',
#  'admin2',
#  'admin3',
#  'location',
#  'latitude',
#  'longitude',
#  'geo_precision',
#  'source',
#  'source_scale',
#  'notes',
#  'fatalities',
#  'timestamp',
#  'iso3']

# %%
'depending on the question we want to ask, we can select columns that might be useful'
subset_df = df[['event_date', 'event_type', 'actor1', 'assoc_actor_1', 'actor2', 'assoc_actor_2','location','latitude','longitude',
   'fatalities','source','source_scale','notes']]
subset_df
# Out:
#         event_date                  event_type  \
# 0      07 May 2021                    Protests
# 1      07 May 2021                    Protests
# 2      07 May 2021                    Protests
# 3      07 May 2021                    Protests
# 4      07 May 2021                    Protests
# ...            ...                         ...
# 35634  07 May 2018                       Riots
# 35635  07 May 2018  Violence against civilians
# 35636  07 May 2018                    Protests
# 35637  07 May 2018                     Battles
# 35638  07 May 2018                     Battles
#
#                                         actor1  \
# 0                          Protesters (Brazil)
# 1                          Protesters (Brazil)
# 2                          Protesters (Brazil)
# 3                          Protesters (Brazil)
# 4                          Protesters (Brazil)
# ...                                        ...
# 35634                         Rioters (Brazil)
# ...

# %%
'What are the different events?'
subset_df.event_type.unique()
# Out:
# array(['Protests', 'Riots', 'Battles', 'Explosions/Remote violence',
#        'Violence against civilians', 'Strategic developments'],
#       dtype=object)

# %%
'What types of actors are there in Brazil?'
subset_df.actor1.unique()
# Out:
# array(['Protesters (Brazil)', 'Rioters (Brazil)',
#        'Military Forces of Brazil (2019-) Military Police',
#        'Unidentified Gang and/or Police Militia',
#        'Unidentified Gang (Brazil)', 'Police Forces of Brazil (2019-)',
#        'Unidentified Armed Group (Brazil)',
#        'Police Forces of Brazil (2019-) Civil Police',
#        'Police Forces of Brazil (2019-) Prison Guards', 'CV: Red Command',
#        'Police Forces of Brazil (2019-) Municipal Guards',
#        'Police Forces of Brazil (2019-) Federal Police',
#        'TCP: Pure Third Command', 'Peace Command',
#        'PCC: First Capital Command', 'Protesters (Cuba)',
#        'ADA: Amigos dos Amigos',
#        'Military Forces of Brazil (2019-) UPP: Pacifying Police Unit',
#        'Police Militia', 'B13: Tram of 13', 'Protesters (Haiti)',
#        'Bala na Cara Gang', 'CDC: Comboio do Cao',
#        'Macaquinho Police Militia', 'Trem Bala Gang',
# ...
